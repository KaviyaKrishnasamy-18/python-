# %%
def addition(a,b):
    addition=a+b
    return addition

# %%
lists=[23,45,67,34,89]

# %%
def Agecategory():
 for age in lists:
    if(age<18):
           print("children")
    elif(age<35):
           print("adult")
    elif(age<60):
           print("citizen")
    else:
           print("senior citizen")

# %%
Agecategory()
# Out:
# adult
# citizen
# senior citizen
# adult
# senior citizen

# %%
age=int(input("enter the age"))
# Out:
# enter the age 45

# %%
def Agecategory():
    if(age<18):
           print("children")
           cate="children"
    elif(age<35):
           print("adult")
           cate="adult"
    elif(age<60):
           print("citizen")
           cate="citizen"
    else:
           print("senior citizen")
           cate="seniorcitizen"
    return cate

# %%
Agecategory()
# Out:
# citizen
# 'citizen'

# %%
agecate=Agecategory()
# Out:
# citizen

# %%
agecate
# Out:
# 'citizen'
