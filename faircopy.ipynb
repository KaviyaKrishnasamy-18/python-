# %%
from multiplefunctions import multiplefunctions

# %%
multiplefunctions.BMI()
# Out:
# enter the BMI index: 24
# normal

# %%
multiplefunctions.BMI()
# Out:
# enter the BMI index: 11
# underweight

# %%
multiplefunctions.oddeven()
# Out:
# enter the number 11
# odd number
